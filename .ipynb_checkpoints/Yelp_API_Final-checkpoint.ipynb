# %%
import pandas as pd
import requests as re
import numpy as np
import folium
import os

# %%
API_KEY = os.environ.get('yelp_key')

# %%
## Setting up the base of the query

lat = '43.65479'
long = '-79.40263693'
limit = '50' ## Max results. Default = 20
radius = 1000
categories = 'query' ## Placeholder

base_url = "https://api.yelp.com/v3/businesses/search"

headers = { 'Authorization' : f'Bearer {API_KEY}'}

params = {
    'categories' : categories,
    'latitude': lat,
    'longitude': long,
    'radius' : radius,
    'limit' : limit
}

# %%
## Getting details on bars

categories = 'nightlife,all'
params = {
    'categories' : categories,
    'latitude': lat,
    'longitude': long,
    'radius' : radius,
    'limit' : limit
}

bars = re.get(url=base_url,headers=headers,params=params)

# %%
bars = bars.json()

bars ## From this we can see that all values fall into the 'businesses' key
# Out:
# {'businesses': [{'id': 'EEIz44ewHhOKmfTloAK13g',
#    'alias': 'alo-restaurant-toronto',
#    'name': 'Alo Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XsnAQmSC1bRBmEhRr4xOdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alo-restaurant-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 288,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.64851, 'longitude': -79.39584},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '163 Spadina Avenue',
#     'address2': '3rd Floor',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5V 2A5',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['163 Spadina Avenue',
#      '3rd Floor',
#      'Toronto, ON M5V 2A5',
#      'Canada']},
#    'phone': '+14162602222',
#    'display_phone': '+1 416-260-2222',
#    'distance': 879.5843380203778},
#   {'id': 'Ibp4hEKSE8JaX9OvfEiFqg',
#    'alias': 'ottos-berlin-döner-toronto-2',
#    'name': "Otto's Berlin Döner",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Nu639wp_gpnILSfVDUjShw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ottos-berlin-d%C3%B6ner-toronto-2?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 256,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.6563397, 'longitude': -79.4029066},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '256 Augusta Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5T 2L9',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['256 Augusta Avenue',
#      'Toronto, ON M5T 2L9',
#      'Canada']},
#    'phone': '+16473477713',
#    'display_phone': '+1 647-347-7713',
#    'distance': 173.6789084840744},
#   {'id': '41o1FUbCYKJv2djtnlkzlg',
#    'alias': 'bar-raval-toronto',
#    'name': 'Bar Raval',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vSHLfEfdrQkJJi7mRk4VFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-raval-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 275,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.6558432, 'longitude': -79.4099433},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '505 College Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M6G 2J3',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['505 College Street',
#      'Toronto, ON M6G 2J3',
#      'Canada']},
#    'phone': '+16473448001',
#    'display_phone': '+1 647-344-8001',
#    'distance': 599.350782165073},
#   {'id': 'h_4dPV9M9aYaBliH1Eoeeg',
#    'alias': 'wvrst-toronto',
#    'name': 'Wvrst',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KgN_5rF-A9unHqf6CYO_gQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wvrst-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 788,
#    'categories': [{'alias': 'german', 'title': 'German'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.64418555054, 'longitude': -79.401014855291},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '609 King Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5V 1M5',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['609 King Street W', 'Toronto, ON M5V 1M5', 'Canada']},
#    'phone': '+14167037775',
#    'display_phone': '+1 416-703-7775',
#    'distance': 1186.3600014176327},
#   {'id': 'jOqh0eVjqtUOpZ9AZgSazA',
#    'alias': 'grey-gardens-toronto',
#    'name': 'Grey Gardens',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zppuNZ_XTk7i4Kz9ZESSoA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grey-gardens-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 95,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'newcanadian', 'title': 'Canadian (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.6537999, 'longitude': -79.40143},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '199 Augusta Avenue',
#     'address2': '',
#     'address3': None,
#     'city': 'Toronto',
#     'zip_code': 'M5T 2L4',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['199 Augusta Avenue',
#      'Toronto, ON M5T 2L4',
#      'Canada']},
#    'phone': '+16473511552',
#    'display_phone': '+1 647-351-1552',
#    'distance': 143.84016045448345},
#   {'id': 'rxA9c0_XObabVL1WCTA4FA',
#    'alias': 'sneaky-dees-toronto',
#    'name': "Sneaky Dee's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xrFqkSseyLiR6TrJ6Eq-_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sneaky-dees-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 444,
#    'categories': [{'alias': 'tex-mex', 'title': 'Tex-Mex'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.6562399, 'longitude': -79.4074},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '431 College Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5T 1T1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['431 College Street',
#      'Toronto, ON M5T 1T1',
#      'Canada']},
#    'phone': '+14166033090',
#    'display_phone': '+1 416-603-3090',
#    'distance': 426.24326515891096},
#   {'id': '47wBHgBwQ8_70sjmXow_1g',
#    'alias': 'her-fathers-cider-bar-and-kitchen-toronto',
#    'name': "Her Father's Cider Bar & Kitchen",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EMlr2YrZKz2qeY2_eSEt1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/her-fathers-cider-bar-and-kitchen-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 155,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newcanadian', 'title': 'Canadian (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.66232, 'longitude': -79.40453},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '119 Harbord Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5S 1G7',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['119 Harbord Street',
#      'Toronto, ON M5S 1G7',
#      'Canada']},
#    'phone': '+16473477747',
#    'display_phone': '+1 647-347-7747',
#    'distance': 852.2362954991446},
#   {'id': 'G12kABl0tfK4ylgj8XF06w',
#    'alias': 'voodoo-child-toronto',
#    'name': 'Voodoo Child',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-TzZJu8KOcbRf2nWIUr4AQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/voodoo-child-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 133,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.65714, 'longitude': -79.40552},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '388 College Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5T 1S7',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['388 College Street',
#      'Toronto, ON M5T 1S7',
#      'Canada']},
#    'phone': '+16477481011',
#    'display_phone': '+1 647-748-1011',
#    'distance': 341.6581487632357},
#   {'id': 'FML0YqZ7dLBBC3Suap4_4Q',
#    'alias': '416-snack-bar-toronto',
#    'name': '416 Snack Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vzG6ArIyZnHSuxlg1KjgsQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/416-snack-bar-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 319,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.64755, 'longitude': -79.40385},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '181 Bathurst Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5T 2R7',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['181 Bathurst Street',
#      'Toronto, ON M5T 2R7',
#      'Canada']},
#    'phone': '+14163649320',
#    'display_phone': '+1 416-364-9320',
#    'distance': 812.4790287884365},
#   {'id': 'dd3GZs6zW2t7BM0cbxAzvg',
#    'alias': 'la-palette-toronto-3',
#    'name': 'La Palette',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/OwYfW0w9yL4ToFM1STNBbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-palette-toronto-3?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 228,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.64797, 'longitude': -79.40098},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '492 Queen Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5V 2B3',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['492 Queen Street W',
#      'Toronto, ON M5V 2B3',
#      'Canada']},
#    'phone': '+14169294900',
#    'display_phone': '+1 416-929-4900',
#    'distance': 769.3362963828135},
#   {'id': '4m_hApwQ054v3ue_OxFmGw',
#    'alias': 'patria-toronto',
#    'name': 'Patria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DwosQ6g-csJNpjOvCzW8DA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patria-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 480,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.6455399, 'longitude': -79.39641},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '480 King Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5V 1L7',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['480 King Street W', 'Toronto, ON M5V 1L7', 'Canada']},
#    'phone': '+14163670505',
#    'display_phone': '+1 416-367-0505',
#    'distance': 1162.3925448085295},
#   {'id': 'e41TP5cXZqSrz50xCBJqZw',
#    'alias': 'insomnia-restaurant-and-lounge-toronto',
#    'name': 'Insomnia Restaurant & Lounge',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rwQeDavE6_e16b8gdV_smw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/insomnia-restaurant-and-lounge-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 921,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.665961, 'longitude': -79.411003},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '563 Bloor Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5S 1Y6',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['563 Bloor Street W',
#      'Toronto, ON M5S 1Y6',
#      'Canada']},
#    'phone': '+14165883907',
#    'display_phone': '+1 416-588-3907',
#    'distance': 1412.7546368409346},
#   {'id': 'ZuA9e5nSrCj2R97x2K2yOQ',
#    'alias': 'cold-tea-toronto',
#    'name': 'Cold Tea',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EGjSQZ4NyXsAKCAaRcoWag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cold-tea-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 150,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.6542015, 'longitude': -79.4009171},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '60 Kensington Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5T 2K2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['60 Kensington Avenue',
#      'Toronto, ON M5T 2K2',
#      'Canada']},
#    'phone': '+14165464536',
#    'display_phone': '+1 416-546-4536',
#    'distance': 158.6367571359945},
#   {'id': 'OURoudNtFXyd7RTtl5ASKg',
#    'alias': 'café-pamenar-toronto-3',
#    'name': 'Café Pamenar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_ewoc6RrAgWuh_7gXDaPAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caf%C3%A9-pamenar-toronto-3?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 107,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.6566765, 'longitude': -79.4027438},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '307 Augusta Avenue',
#     'address2': None,
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5T 2M2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['307 Augusta Avenue',
#      'Toronto, ON M5T 2M2',
#      'Canada']},
#    'phone': '+16473523627',
#    'display_phone': '+1 647-352-3627',
#    'distance': 209.9451149483201},
#   {'id': 'qNCt4Dx3S0R-n3x39mxxLw',
#    'alias': 'tilt-arcade-bar-toronto',
#    'name': 'Tilt Arcade Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/f9VpdFMKswM_rDQsNKK7Uw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tilt-arcade-bar-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 84,
#    'categories': [{'alias': 'arcades', 'title': 'Arcades'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.65182, 'longitude': -79.40925},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '824 Dundas Street West',
#     'address2': None,
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M6J 1V3',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['824 Dundas Street West',
#      'Toronto, ON M6J 1V3',
#      'Canada']},
#    'phone': '+14165518458',
#    'display_phone': '+1 416-551-8458',
#    'distance': 631.5444707382582},
#   {'id': 'wS8cgjFJFKgdfbRmz3pjTA',
#    'alias': 'handlebar-toronto',
#    'name': 'Handlebar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/R1KDWOzLEjZna7Q4y9xUTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/handlebar-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 57,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'danceclubs', 'title': 'Dance Clubs'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.6528604406984,
#     'longitude': -79.4012188911438},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '159 Augusta Avenue',
#     'address2': 'Main Floor',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5T 2L4',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['159 Augusta Avenue',
#      'Main Floor',
#      'Toronto, ON M5T 2L4',
#      'Canada']},
#    'phone': '+16477487433',
#    'display_phone': '+1 647-748-7433',
#    'distance': 243.00183034338565},
#   {'id': 'CZY3743GpOOhdDJu6UmPBA',
#    'alias': 'bar-buca-toronto',
#    'name': 'Bar Buca',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/e9LoFlVVuK8EoEYoL_nxHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-buca-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 260,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.6439229362435,
#     'longitude': -79.3998403851863},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '75 Portland Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5V',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['75 Portland Street', 'Toronto, ON M5V', 'Canada']},
#    'phone': '+14165992822',
#    'display_phone': '+1 416-599-2822',
#    'distance': 1229.1311587264534},
#   {'id': 'ehUN_XAWr1ePov0jtgv0Lw',
#    'alias': 'snakes-and-lattes-college-toronto-4',
#    'name': 'Snakes & Lattes College',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dx2K_nWyxm_m0tZbiamieQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/snakes-and-lattes-college-toronto-4?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 146,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'tabletopgames', 'title': 'Tabletop Games'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.6560199874864,
#     'longitude': -79.4090836992892},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '489 College Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M6G 1A5',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['489 College Street',
#      'Toronto, ON M6G 1A5',
#      'Canada']},
#    'phone': '+16473429229',
#    'display_phone': '+1 647-342-9229',
#    'distance': 536.3724478669801},
#   {'id': 'rRpKagtOV4PWOib7JQOFoQ',
#    'alias': 'demen-bistro-toronto',
#    'name': 'Demen Bistro',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DGyQAuc0Wf4y2pO1OLb35Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/demen-bistro-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 41,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.6479352959741,
#     'longitude': -79.4012527540326},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '500 Queen Street W',
#     'address2': '',
#     'address3': None,
#     'city': 'Toronto',
#     'zip_code': 'M5V 2B6',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['500 Queen Street W',
#      'Toronto, ON M5V 2B6',
#      'Canada']},
#    'phone': '+14163642888',
#    'display_phone': '+1 416-364-2888',
#    'distance': 770.3001035857981},
#   {'id': 'pK83jG-vw6UykrHkwWC_IQ',
#    'alias': 'poetry-jazz-cafe-toronto',
#    'name': 'Poetry Jazz Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7wPEkAr15mZcA2jjWRqBmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/poetry-jazz-cafe-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 50,
#    'categories': [{'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.65493, 'longitude': -79.40242},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '224 Augusta Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5T 1M5',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['224 Augusta Avenue',
#      'Toronto, ON M5T 1M5',
#      'Canada']},
#    'phone': '+14165995299',
#    'display_phone': '+1 416-599-5299',
#    'distance': 24.431993164828377},
#   {'id': 'QfJq6e35noUm03mZbzSNCg',
#    'alias': 'thirsty-and-miserable-toronto',
#    'name': 'Thirsty & Miserable',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/b6zzjiwxHTACkgPTlXCWbw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thirsty-and-miserable-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 58,
#    'categories': [{'alias': 'divebars', 'title': 'Dive Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.6544914, 'longitude': -79.4015503},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '197 Baldwin Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5T 1M1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['197 Baldwin Street',
#      'Toronto, ON M5T 1M1',
#      'Canada']},
#    'phone': '+16476070134',
#    'display_phone': '+1 647-607-0134',
#    'distance': 90.90335244191388},
#   {'id': 'WP1e-VmnTW2K0A9dMCF10g',
#    'alias': 'canis-toronto',
#    'name': 'Canis',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vwp-9MTF3Rs9MFgdelc4Ng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/canis-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 75,
#    'categories': [{'alias': 'newcanadian', 'title': 'Canadian (New)'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.6460933596731,
#     'longitude': -79.4101145473278},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '746 Queen Street W',
#     'address2': '',
#     'address3': None,
#     'city': 'Toronto',
#     'zip_code': 'M6J 1E9',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['746 Queen Street W',
#      'Toronto, ON M6J 1E9',
#      'Canada']},
#    'phone': '+14162033317',
#    'display_phone': '+1 416-203-3317',
#    'distance': 1138.8946937419073},
#   {'id': 'W0_0cHCJl-eNxKBcjjXE0g',
#    'alias': 'big-trouble-toronto',
#    'name': 'Big Trouble',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AJH7CButk4EuhcnyYZxiHw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/big-trouble-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 64,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.653366711621,
#     'longitude': -79.3964891508222},
#    'transactions': [],
#    'location': {'address1': '460 Dundas Street W',
#     'address2': 'Suite 200',
#     'address3': None,
#     'city': 'Toronto',
#     'zip_code': 'M5T 1G9',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['460 Dundas Street W',
#      'Suite 200',
#      'Toronto, ON M5T 1G9',
#      'Canada']},
#    'phone': '+16473478880',
#    'display_phone': '+1 647-347-8880',
#    'distance': 519.3030115709919},
#   {'id': 'Zx-rz7D4DOT8Kmx97LFAjw',
#    'alias': 'ronnies-local-069-toronto',
#    'name': "Ronnie's Local 069",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SCuIrpgkH9TK3HdXoslqTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ronnies-local-069-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 73,
#    'categories': [{'alias': 'divebars', 'title': 'Dive Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.655, 'longitude': -79.4026},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '69 Nassau St',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5T 1M6',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['69 Nassau St', 'Toronto, ON M5T 1M6', 'Canada']},
#    'phone': '+14163401110',
#    'display_phone': '+1 416-340-1110',
#    'distance': 22.228896485553552},
#   {'id': 'bDgmLfAh_TWRCHEYC8hbpQ',
#    'alias': 'the-keg-steakhouse-and-bar-toronto-5',
#    'name': 'The Keg Steakhouse & Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GKeNGKFlvkH9k6G-T43J-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-keg-steakhouse-and-bar-toronto-5?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 117,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.6448066525519,
#     'longitude': -79.3990968746814},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '560 King Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5V 1M3',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['560 King Street W', 'Toronto, ON M5V 1M3', 'Canada']},
#    'phone': '+14163647227',
#    'display_phone': '+1 416-364-7227',
#    'distance': 1146.0534754178143},
#   {'id': 'oKZPgeCOxnVSxudYcn1OtQ',
#    'alias': 'cibo-wine-bar-toronto-11',
#    'name': 'Cibo Wine Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kYlCtlCb9mHB7QL2HmX1iQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cibo-wine-bar-toronto-11?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 321,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.64521, 'longitude': -79.39737},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '522 King Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5V 1L7',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['522 King Street W', 'Toronto, ON M5V 1L7', 'Canada']},
#    'phone': '+14165043939',
#    'display_phone': '+1 416-504-3939',
#    'distance': 1142.1761098769352},
#   {'id': 'aNZa21WWMc-2HpToNDMhHg',
#    'alias': 'the-boat-toronto',
#    'name': 'The Boat',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TCUKvOzHfdzLah-3NQC7tA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-boat-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 41,
#    'categories': [{'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.6527672883244,
#     'longitude': -79.4013476371765},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '158 Augusta Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5T 2L5',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['158 Augusta Avenue',
#      'Toronto, ON M5T 2L5',
#      'Canada']},
#    'phone': '+14165939218',
#    'display_phone': '+1 416-593-9218',
#    'distance': 247.6811009624339},
#   {'id': 'R3iom4lNTG-9A6qczf6V8w',
#    'alias': 'java-house-toronto',
#    'name': 'Java House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UqPcMpMc5kZ3oW80W3sEyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/java-house-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 180,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.64784, 'longitude': -79.39975},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '537 Queen St W',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5V 2B6',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['537 Queen St W', 'Toronto, ON M5V 2B6', 'Canada']},
#    'phone': '+14165043025',
#    'display_phone': '+1 416-504-3025',
#    'distance': 808.4038256236415},
#   {'id': 'jCiovc2qHJ5L-_1gigLueQ',
#    'alias': 'weslodge-bar-and-grill-toronto',
#    'name': 'Weslodge Bar & Grill',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/zW2RVUhYl-z-zBkfNA9N2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/weslodge-bar-and-grill-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 257,
#    'categories': [{'alias': 'newcanadian', 'title': 'Canadian (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.64554, 'longitude': -79.39641},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '480 King Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5V 1L7',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['480 King Street W', 'Toronto, ON M5V 1L7', 'Canada']},
#    'phone': '+16476600999',
#    'display_phone': '+1 647-660-0999',
#    'distance': 1162.3925448085295},
#   {'id': 'O9Ukz3F4BW_MbvLnaQYxRg',
#    'alias': 'supermarket-restaurant-and-bar-toronto-2',
#    'name': 'Supermarket Restaurant and Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/znFnjtbwvksFG5DXBmUBnQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/supermarket-restaurant-and-bar-toronto-2?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 78,
#    'categories': [{'alias': 'newcanadian', 'title': 'Canadian (New)'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'danceclubs', 'title': 'Dance Clubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.6564466972306,
#     'longitude': -79.4029140472412},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '268 Augusta Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5T 2L9',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['268 Augusta Avenue',
#      'Toronto, ON M5T 2L9',
#      'Canada']},
#    'phone': '+14168400501',
#    'display_phone': '+1 416-840-0501',
#    'distance': 185.56023797679958},
#   {'id': 'gpQzoaeFGw3QfzVf7Dx07g',
#    'alias': 'montauk-bar-toronto',
#    'name': 'Montauk Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cw0OqT807EBO9FyP9pHwew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/montauk-bar-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 53,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.652115, 'longitude': -79.4068536},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '765 Dundas Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M6J 1T9',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['765 Dundas Street W',
#      'Toronto, ON M6J 1T9',
#      'Canada']},
#    'phone': '+16478236910',
#    'display_phone': '+1 647-823-6910',
#    'distance': 451.17544977218813},
#   {'id': 'bRmb81XDG3E2SOHARBLTog',
#    'alias': 'bodega-restaurant-toronto-2',
#    'name': 'Bodega Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hBA6e4k6dTTeOQ-GdZhdLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bodega-restaurant-toronto-2?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 127,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.6561, 'longitude': -79.39369},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '30 Baldwin St',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5T 1L3',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['30 Baldwin St', 'Toronto, ON M5T 1L3', 'Canada']},
#    'phone': '+14169771287',
#    'display_phone': '+1 416-977-1287',
#    'distance': 730.8974009713938},
#   {'id': '2i0dDzxLuQQAwzxDZVR-1g',
#    'alias': 'oretta-toronto',
#    'name': 'Oretta',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SiH7VUA2rMcHwxDcuVllbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oretta-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 255,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.64392, 'longitude': -79.40163},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '633 King Street W',
#     'address2': '',
#     'address3': None,
#     'city': 'Toronto',
#     'zip_code': 'M5V 1M5',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['633 King Street W', 'Toronto, ON M5V 1M5', 'Canada']},
#    'phone': '+14169441932',
#    'display_phone': '+1 416-944-1932',
#    'distance': 1211.6829040369912},
#   {'id': '4SyAKQevPuB4punANp41-Q',
#    'alias': 'el-rey-mezcal-bar-toronto',
#    'name': 'El Rey Mezcal Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Lxm-2rlbhqByXGcvouL9DQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-rey-mezcal-bar-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 61,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.6528135234028,
#     'longitude': -79.4000687706962},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2A Kensington Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5T 2J7',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['2A Kensington Avenue',
#      'Toronto, ON M5T 2J7',
#      'Canada']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 301.6452412881354},
#   {'id': 'kaW97gZXyGMdkedZNdQuew',
#    'alias': 'harbord-house-toronto',
#    'name': 'Harbord House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pfF-n-agwvaZfhCox_ULXw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harbord-house-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 107,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'newcanadian', 'title': 'Canadian (New)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.6625, 'longitude': -79.40545},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '150 Harbord Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5S 1H2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['150 Harbord Street',
#      'Toronto, ON M5S 1H2',
#      'Canada']},
#    'phone': '+16474307365',
#    'display_phone': '+1 647-430-7365',
#    'distance': 882.2557287944228},
#   {'id': 'fgTeVSSrqqCR1VDWMUgaKw',
#    'alias': 'koi-koi-saké-bar-toronto',
#    'name': 'Koi Koi Saké Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_-oGwaKOEWHAGrZ0jRDFbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/koi-koi-sak%C3%A9-bar-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 43,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.65499, 'longitude': -79.40054},
#    'transactions': [],
#    'location': {'address1': '170 Baldwin Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5T 1L8',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['170 Baldwin Street',
#      'Toronto, ON M5T 1L8',
#      'Canada']},
#    'phone': '+16473434618',
#    'display_phone': '+1 647-343-4618',
#    'distance': 164.8129336815177},
#   {'id': '7ppWunvrIURnEZi5nUB_7g',
#    'alias': 'baro-toronto-4',
#    'name': 'Baro',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0Kraa-5wXqSPm8-0iMJyXg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baro-toronto-4?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 150,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#     {'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.644906, 'longitude': -79.39694},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '485 King Street W',
#     'address2': '',
#     'address3': None,
#     'city': 'Toronto',
#     'zip_code': 'M5V 1K4',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['485 King Street W', 'Toronto, ON M5V 1K4', 'Canada']},
#    'phone': '+14163638388',
#    'display_phone': '+1 416-363-8388',
#    'distance': 1190.7996164872363},
#   {'id': 'gyPmHqIqC5-RAAy51oiafQ',
#    'alias': 'the-cloak-bar-toronto-2',
#    'name': 'The Cloak Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GJasgsjdSHXggq0rBYv_rQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-cloak-bar-toronto-2?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 77,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.6435, 'longitude': -79.3985},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '488 Wellington Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5V 1E3',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['488 Wellington Street W',
#      'Toronto, ON M5V 1E3',
#      'Canada']},
#    'phone': '+14167107697',
#    'display_phone': '+1 416-710-7697',
#    'distance': 1288.651878880961},
#   {'id': 'Kal1hFMTEzdXYpa5MNzUPw',
#    'alias': 'spin-toronto-toronto',
#    'name': 'SPIN Toronto',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qzuPUVcxAcyQjpeRl5Ztcw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spin-toronto-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 132,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'sports_clubs', 'title': 'Sports Clubs'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.6447886395145,
#     'longitude': -79.3963426351547},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '461 King St W',
#     'address2': 'Lower Level',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5V 1K4',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['461 King St W',
#      'Lower Level',
#      'Toronto, ON M5V 1K4',
#      'Canada']},
#    'phone': '+14165997746',
#    'display_phone': '+1 416-599-7746',
#    'distance': 1221.9775959025792},
#   {'id': 'hPXGBV0HmLNvOOWNVPRvBw',
#    'alias': 'the-horseshoe-tavern-toronto',
#    'name': 'The Horseshoe Tavern',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ZPc1MDApDrvneYjVdtXAaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-horseshoe-tavern-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 102,
#    'categories': [{'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'divebars', 'title': 'Dive Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.6491, 'longitude': -79.39584},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '370 Queen Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5V 2A2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['370 Queen Street W',
#      'Toronto, ON M5V 2A2',
#      'Canada']},
#    'phone': '+14165982162',
#    'display_phone': '+1 416-598-2162',
#    'distance': 816.635176982399},
#   {'id': 'aRvCyCpwxgIqjXSSZ8pt3g',
#    'alias': 'mallo-toronto',
#    'name': 'Mallo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GSo9vxJEBgCUfBQRlPBU-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mallo-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 37,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 43.6646307, 'longitude': -79.4107376},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '785  Bathurst Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5R 3G3',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['785  Bathurst Street',
#      'Toronto, ON M5R 3G3',
#      'Canada']},
#    'phone': '+16475209219',
#    'display_phone': '+1 647-520-9219',
#    'distance': 1273.5775187505262},
#   {'id': '2Wff1lKhXu56Rdsf0omDGA',
#    'alias': 'rivoli-cafe-and-club-toronto',
#    'name': 'Rivoli Cafe & Club',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rcJeblmMUs6QkDVy0MQdSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rivoli-cafe-and-club-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 136,
#    'categories': [{'alias': 'poolhalls', 'title': 'Pool Halls'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'newcanadian', 'title': 'Canadian (New)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.64928, 'longitude': -79.39496},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '334 Queen St W',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5V 2A2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['334 Queen St W', 'Toronto, ON M5V 2A2', 'Canada']},
#    'phone': '+14165961908',
#    'display_phone': '+1 416-596-1908',
#    'distance': 866.7473882809779},
#   {'id': 'BN7KeClLq8DR-crgAImpcQ',
#    'alias': 'trinity-common-toronto',
#    'name': 'Trinity Common',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/oAdCqFqOne1kMq1h8iu_BQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trinity-common-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 82,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 43.6567508787794,
#     'longitude': -79.4030518457294},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '303 Augusta Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5T 2M2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['303 Augusta Avenue',
#      'Toronto, ON M5T 2M2',
#      'Canada']},
#    'phone': '+16473463030',
#    'display_phone': '+1 647-346-3030',
#    'distance': 220.57979156583855},
#   {'id': '1I3PnP5FSkur8AXp6izLOw',
#    'alias': 'the-dime-toronto',
#    'name': 'The Dime',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iHEijpap6-W-ZGtGrxIOdw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-dime-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 76,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.6476526616345,
#     'longitude': -79.4026391208172},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '538 Queen Street West',
#     'address2': '',
#     'address3': None,
#     'city': 'Toronto',
#     'zip_code': 'M5V 2B5',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['538 Queen Street West',
#      'Toronto, ON M5V 2B5',
#      'Canada']},
#    'phone': '+16473489080',
#    'display_phone': '+1 647-348-9080',
#    'distance': 793.6349553403721},
#   {'id': 'CLNqviorDO-pQvxTTy3kbA',
#    'alias': 'green-room-toronto',
#    'name': 'Green Room',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Q5FB0KDCJADpGSdMo282Iw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/green-room-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 121,
#    'categories': [{'alias': 'divebars', 'title': 'Dive Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 43.65691, 'longitude': -79.40679},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '414 College Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5T 1T3',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['414 College Street',
#      'Toronto, ON M5T 1T3',
#      'Canada']},
#    'phone': '+14169293253',
#    'display_phone': '+1 416-929-3253',
#    'distance': 401.67178995335104},
#   {'id': 'bYGn37k0KgleABKMWgjnMw',
#    'alias': 'el-furniture-warehouse-bloor-st-toronto',
#    'name': 'El Furniture Warehouse - Bloor St',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RU2UBTzK0ubz-x-WeRwvug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-furniture-warehouse-bloor-st-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 309,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 43.6659060524241,
#     'longitude': -79.4080606117255},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '410 Bloor St West',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5S 1X5',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['410 Bloor St West', 'Toronto, ON M5S 1X5', 'Canada']},
#    'phone': '+16473597326',
#    'display_phone': '+1 647-359-7326',
#    'distance': 1310.7897222766012},
#   {'id': '9-4UtP9kdunfJl-DvudTeg',
#    'alias': 'bovine-sex-club-toronto',
#    'name': 'Bovine Sex Club',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lGIAKSxpKH80tkhI4SuBVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bovine-sex-club-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 47,
#    'categories': [{'alias': 'divebars', 'title': 'Dive Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.6487959140891,
#     'longitude': -79.4026722255839},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '542 Queen Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5V 2B5',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['542 Queen Street W',
#      'Toronto, ON M5V 2B5',
#      'Canada']},
#    'phone': '+14165044239',
#    'display_phone': '+1 416-504-4239',
#    'distance': 666.5172532358762},
#   {'id': 'qcqDjeirxvdgW5kQVkEwSA',
#    'alias': 'the-red-room-toronto',
#    'name': 'The Red Room',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5XGQAHWlFPox8E-_us-DzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-red-room-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 135,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'newcanadian', 'title': 'Canadian (New)'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 43.65706, 'longitude': -79.40011},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '444 Spadina Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5T 2G8',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['444 Spadina Avenue',
#      'Toronto, ON M5T 2G8',
#      'Canada']},
#    'phone': '+14169299964',
#    'display_phone': '+1 416-929-9964',
#    'distance': 322.85544199532836},
#   {'id': 'sXg2NCfiCqK_X_4R5NK_jQ',
#    'alias': 'barchef-toronto',
#    'name': 'BarChef',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KhWy0NUdQkhhd9SFQ7upbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barchef-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 341,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.6482201, 'longitude': -79.4001694},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '472 Queen Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5V 2B2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['472 Queen Street W',
#      'Toronto, ON M5V 2B2',
#      'Canada']},
#    'phone': '+14168684800',
#    'display_phone': '+1 416-868-4800',
#    'distance': 757.0331915725939},
#   {'id': 'YTCSaFHzEZJkdG56gxY9aA',
#    'alias': 'cameron-house-toronto',
#    'name': 'Cameron House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ccP5l7vje_OjhBxdJl0jew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cameron-house-toronto?adjust_creative=Pxmv99W7YIcocwCQezJD5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pxmv99W7YIcocwCQezJD5A',
#    'review_count': 37,
#    'categories': [{'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.6485287024574,
#     'longitude': -79.3975496292114},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '408 Queen Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5V 2A7',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['408 Queen Street W',
#      'Toronto, ON M5V 2A7',
#      'Canada']},
#    'phone': '+14167030811',
#    'display_phone': '+1 416-703-0811',
#    'distance': 807.6217585034626}],
#  'total': 179,
#  'region': {'center': {'longitude': -79.40263693, 'latitude': 43.65479}}}

# %%
bars = bars['businesses']
bars_df = pd.DataFrame(bars)

# %%
bars_df.head() ## Drop all unnecessary columns
# Out:
#                        id                         alias                 name  \
# 0  EEIz44ewHhOKmfTloAK13g        alo-restaurant-toronto       Alo Restaurant
# 1  Ibp4hEKSE8JaX9OvfEiFqg  ottos-berlin-döner-toronto-2  Otto's Berlin Döner
# 2  41o1FUbCYKJv2djtnlkzlg             bar-raval-toronto            Bar Raval
# 3  h_4dPV9M9aYaBliH1Eoeeg                 wvrst-toronto                Wvrst
# 4  jOqh0eVjqtUOpZ9AZgSazA          grey-gardens-toronto         Grey Gardens
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/XsnAQm...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/Nu639w...      False
# 2  https://s3-media4.fl.yelpcdn.com/bphoto/vSHLfE...      False
# 3  https://s3-media4.fl.yelpcdn.com/bphoto/KgN_5r...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/zppuNZ...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/alo-restaurant-toront...           288
# 1  https://www.yelp.com/biz/ottos-berlin-d%C3%B6n...           256
# 2  https://www.yelp.com/biz/bar-raval-toronto?adj...           275
# 3  https://www.yelp.com/biz/wvrst-toronto?adjust_...           788
# 4  https://www.yelp.com/biz/grey-gardens-toronto?...            95
#
#                                           categories  rating  \
# 0  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.5
# 1  [{'alias': 'german', 'title': 'German'}, {'ali...     4.0
# 2  [{'alias': 'spanish', 'title': 'Spanish'}, {'a...     4.0
# 3  [{'alias': 'german', 'title': 'German'}, {'ali...     4.0
# 4  [{'alias': 'wine_bars', 'title': 'Wine Bars'},...     4.5
#
#                                          coordinates transactions price  \
# 0     {'latitude': 43.64851, 'longitude': -79.39584}           []  $$$$
# 1  {'latitude': 43.6563397, 'longitude': -79.4029...           []    $$
# 2  {'latitude': 43.6558432, 'longitude': -79.4099...           []   $$$
# 3  {'latitude': 43.64418555054, 'longitude': -79....           []    $$
# 4   {'latitude': 43.6537999, 'longitude': -79.40143}           []   $$$
#
#                                             location         phone  \
# 0  {'address1': '163 Spadina Avenue', 'address2':...  +14162602222
# 1  {'address1': '256 Augusta Avenue', 'address2':...  +16473477713
# 2  {'address1': '505 College Street', 'address2':...  +16473448001
# 3  {'address1': '609 King Street W', 'address2': ...  +14167037775
# 4  {'address1': '199 Augusta Avenue', 'address2':...  +16473511552
#
#      display_phone     distance
# 0  +1 416-260-2222   879.584338
# 1  +1 647-347-7713   173.678908
# 2  +1 647-344-8001   599.350782
# 3  +1 416-703-7775  1186.360001
# 4  +1 647-351-1552   143.840160

# %%
bars_df = bars_df.drop(labels=['alias', 'image_url', 'is_closed', 'url', 
                    'transactions', 'phone', 'display_phone', 'distance', 'categories', 'id', 'location'], axis=1)

# %%
bars_df ## Coordinates have to be cleaned up
# Out:
#                                  name  review_count  rating  \
# 0                      Alo Restaurant           288     4.5
# 1                 Otto's Berlin Döner           256     4.0
# 2                           Bar Raval           275     4.0
# 3                               Wvrst           788     4.0
# 4                        Grey Gardens            95     4.5
# 5                        Sneaky Dee's           444     3.5
# 6    Her Father's Cider Bar & Kitchen           155     4.5
# 7                        Voodoo Child           133     4.0
# 8                       416 Snack Bar           319     4.0
# 9                          La Palette           228     4.0
# 10                             Patria           480     4.0
# 11       Insomnia Restaurant & Lounge           921     4.0
# 12                           Cold Tea           150     3.5
# 13                       Café Pamenar           107     4.0
# 14                    Tilt Arcade Bar            84     4.5
# 15                          Handlebar            57     4.5
# 16                           Bar Buca           260     4.0
# 17            Snakes & Lattes College           146     3.5
# 18                       Demen Bistro            41     4.5
# 19                   Poetry Jazz Cafe            50     4.0
# 20                Thirsty & Miserable            58     3.5
# 21                              Canis            75     4.5
# 22                        Big Trouble            64     4.0
# 23                 Ronnie's Local 069            73     3.5
# 24           The Keg Steakhouse & Bar           117     4.0
# 25                      Cibo Wine Bar           321     3.5
# 26                           The Boat            41     4.0
# 27                         Java House           180     3.5
# 28               Weslodge Bar & Grill           257     3.5
# 29     Supermarket Restaurant and Bar            78     3.5
# 30                        Montauk Bar            53     4.0
# 31                  Bodega Restaurant           127     3.5
# 32                             Oretta           255     3.5
# 33                  El Rey Mezcal Bar            61     3.5
# 34                      Harbord House           107     3.5
# 35                   Koi Koi Saké Bar            43     3.5
# 36                               Baro           150     3.5
# 37                      The Cloak Bar            77     4.0
# 38                       SPIN Toronto           132     4.0
# 39               The Horseshoe Tavern           102     3.5
# 40                              Mallo            37     5.0
# 41                 Rivoli Cafe & Club           136     3.5
# 42                     Trinity Common            82     3.0
# 43                           The Dime            76     3.5
# 44                         Green Room           121     3.0
# 45  El Furniture Warehouse - Bloor St           309     3.0
# 46                    Bovine Sex Club            47     4.0
# 47                       The Red Room           135     3.0
# 48                            BarChef           341     4.5
# 49                      Cameron House            37     4.0
#
#                                           coordinates price
# 0      {'latitude': 43.64851, 'longitude': -79.39584}  $$$$
# 1   {'latitude': 43.6563397, 'longitude': -79.4029...    $$
# 2   {'latitude': 43.6558432, 'longitude': -79.4099...   $$$
# 3   {'latitude': 43.64418555054, 'longitude': -79....    $$
# 4    {'latitude': 43.6537999, 'longitude': -79.40143}   $$$
# 5     {'latitude': 43.6562399, 'longitude': -79.4074}    $$
# 6      {'latitude': 43.66232, 'longitude': -79.40453}    $$
# 7      {'latitude': 43.65714, 'longitude': -79.40552}    $$
# 8      {'latitude': 43.64755, 'longitude': -79.40385}    $$
# 9      {'latitude': 43.64797, 'longitude': -79.40098}   $$$
# 10   {'latitude': 43.6455399, 'longitude': -79.39641}   $$$
# 11   {'latitude': 43.665961, 'longitude': -79.411003}    $$
# 12  {'latitude': 43.6542015, 'longitude': -79.4009...    $$
# 13  {'latitude': 43.6566765, 'longitude': -79.4027...    $$
# 14     {'latitude': 43.65182, 'longitude': -79.40925}     $
# 15  {'latitude': 43.6528604406984, 'longitude': -7...    $$
# 16  {'latitude': 43.6439229362435, 'longitude': -7...    $$
# 17  {'latitude': 43.6560199874864, 'longitude': -7...    $$
# 18  {'latitude': 43.6479352959741, 'longitude': -7...    $$
# 19     {'latitude': 43.65493, 'longitude': -79.40242}    $$
# 20  {'latitude': 43.6544914, 'longitude': -79.4015...    $$
# 21  {'latitude': 43.6460933596731, 'longitude': -7...   $$$
# 22  {'latitude': 43.653366711621, 'longitude': -79...   NaN
# 23        {'latitude': 43.655, 'longitude': -79.4026}     $
# 24  {'latitude': 43.6448066525519, 'longitude': -7...   $$$
# 25     {'latitude': 43.64521, 'longitude': -79.39737}    $$
# 26  {'latitude': 43.6527672883244, 'longitude': -7...     $
# 27     {'latitude': 43.64784, 'longitude': -79.39975}     $
# 28     {'latitude': 43.64554, 'longitude': -79.39641}   $$$
# 29  {'latitude': 43.6564466972306, 'longitude': -7...    $$
# 30  {'latitude': 43.652115, 'longitude': -79.4068536}    $$
# 31      {'latitude': 43.6561, 'longitude': -79.39369}   $$$
# 32     {'latitude': 43.64392, 'longitude': -79.40163}   $$$
# 33  {'latitude': 43.6528135234028, 'longitude': -7...    $$
# 34      {'latitude': 43.6625, 'longitude': -79.40545}    $$
# 35     {'latitude': 43.65499, 'longitude': -79.40054}   NaN
# 36    {'latitude': 43.644906, 'longitude': -79.39694}   $$$
# 37       {'latitude': 43.6435, 'longitude': -79.3985}    $$
# 38  {'latitude': 43.6447886395145, 'longitude': -7...    $$
# 39      {'latitude': 43.6491, 'longitude': -79.39584}    $$
# 40  {'latitude': 43.6646307, 'longitude': -79.4107...     $
# 41     {'latitude': 43.64928, 'longitude': -79.39496}    $$
# 42  {'latitude': 43.6567508787794, 'longitude': -7...    $$
# 43  {'latitude': 43.6476526616345, 'longitude': -7...     $
# 44     {'latitude': 43.65691, 'longitude': -79.40679}     $
# 45  {'latitude': 43.6659060524241, 'longitude': -7...     $
# 46  {'latitude': 43.6487959140891, 'longitude': -7...     $
# 47     {'latitude': 43.65706, 'longitude': -79.40011}     $
# 48  {'latitude': 43.6482201, 'longitude': -79.4001...   $$$
# 49  {'latitude': 43.6485287024574, 'longitude': -7...     $

# %%
loc_dict = dict(bars_df['coordinates'])

# %%
## loc_dict

# %%
lat = []
long = []
for i in loc_dict.keys():
    latitude = loc_dict[i]['latitude']
    lat.append(latitude)
    longitude = loc_dict[i]['longitude']
    long.append(longitude)

# %%
bars_df['lat'] = lat
bars_df['long'] = long
bars_df['category'] = 'Nightlife' ## Add a category, will be useful later

# %%
bars_df.head(2)
# Out:
#                   name  review_count  rating price       lat       long  \
# 0       Alo Restaurant           288     4.5  $$$$  43.64851 -79.395840
# 1  Otto's Berlin Döner           256     4.0    $$  43.65634 -79.402907
#
#     category
# 0  Nightlife
# 1  Nightlife

# %%
## Repeat process for restaurants

lat = '43.65479'
long = '-79.40263693' ## Redefine cos I stupidly used the same name for the list of coords earlier

categories = 'restaurants,all'
params = {
    'categories' : categories,
    'latitude': lat,
    'longitude': long,
    'radius' : radius,
    'limit' : limit
}

rests = re.get(url=base_url,headers=headers,params=params)
rests = rests.json()

# %%
rests = rests['businesses']
df_rests = pd.DataFrame(rests)

# %%
df_rests = df_rests.drop(labels=['alias', 'image_url', 'is_closed', 'url', 
                    'transactions', 'phone', 'display_phone', 'distance', 'categories', 'id', 'location'], axis=1)

# %%
rests_df = df_rests
loc_dict = dict(rests_df['coordinates'])

# %%
lat = []
long = []
for i in loc_dict.keys():
    latitude = loc_dict[i]['latitude']
    lat.append(latitude)
    longitude = loc_dict[i]['longitude']
    long.append(longitude)

# %%
rests_df['lat'] = lat
rests_df['long'] = long
rests_df['category'] = 'Restaurants' ## Add a category, will be useful later
rests_df = rests_df.drop(labels = 'coordinates', axis = 1)

# %%
rests_df.head() ## Tidy
# Out:
#                            name  review_count  rating price        lat  \
# 0  Seven Lives Tacos y Mariscos          1304     4.5     $  43.654341
# 1                  Ramen Isshin           699     4.5    $$  43.656340
# 2         Fresco's Fish & Chips           354     4.5    $$  43.653834
# 3                  Banh Mi Boys          1109     4.5     $  43.648840
# 4                Juicy Dumpling           473     4.0     $  43.652520
#
#         long     category
# 0 -79.400480  Restaurants
# 1 -79.406890  Restaurants
# 2 -79.401548  Restaurants
# 3 -79.396950  Restaurants
# 4 -79.398540  Restaurants

# %%
## Map visualization using Folium

map_to = folium.Map(location=[43.6537383,-79.4047757], zoom_start=10)
for lat, long, bars in zip(bars_df['lat'], bars_df['long'], bars_df['name']):
    label = '{}'.format(bars)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, long],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.5,
        parse_html=False).add_to(map_to)

# %%
for lat, long, rests in zip(rests_df['lat'], rests_df['long'], rests_df['name']):
    label = '{}'.format(rests)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, long],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='#cc4b31',
        fill_opacity=0.5,
        parse_html=False).add_to(map_to)

# %%
map_to
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
## Creating a finalized table for POIs
POI_df = bars_df.append(rests_df)

# %%
POI_df.head(5)
# Out:
#                   name  review_count  rating price        lat       long  \
# 0       Alo Restaurant           288     4.5  $$$$  43.648510 -79.395840
# 1  Otto's Berlin Döner           256     4.0    $$  43.656340 -79.402907
# 2            Bar Raval           275     4.0   $$$  43.655843 -79.409943
# 3                Wvrst           788     4.0    $$  43.644186 -79.401015
# 4         Grey Gardens            95     4.5   $$$  43.653800 -79.401430
#
#     category
# 0  Nightlife
# 1  Nightlife
# 2  Nightlife
# 3  Nightlife
# 4  Nightlife

# %%
POI_df.tail(5)
# Out:
#                    name  review_count  rating price        lat       long  \
# 45   Fudao noodle house           126     4.0    $$  43.654610 -79.399050
# 46          A-Game Cafe            93     4.5     $  43.651719 -79.407911
# 47  La Chilaca Taqueria            53     4.5     $  43.654581 -79.402468
# 48       Homemade Ramen           252     4.0    $$  43.652410 -79.397390
# 49     Top Gun  Burgers           174     4.0    $$  43.655070 -79.401950
#
#        category
# 45  Restaurants
# 46  Restaurants
# 47  Restaurants
# 48  Restaurants
# 49  Restaurants

# %%
## Sort by popularity
POI_df = POI_df.sort_values('review_count', ascending=False)

# %%
POI_df.head()
# Out:
#                             name  review_count  rating price        lat  \
# 0   Seven Lives Tacos y Mariscos          1304     4.5     $  43.654341
# 3                   Banh Mi Boys          1109     4.5     $  43.648840
# 18                     Gusto 101           974     4.0    $$  43.645002
# 11  Insomnia Restaurant & Lounge           921     4.0    $$  43.665961
# 3                          Wvrst           788     4.0    $$  43.644186
#
#          long     category
# 0  -79.400480  Restaurants
# 3  -79.396950  Restaurants
# 18 -79.400309  Restaurants
# 11 -79.411003    Nightlife
# 3  -79.401015    Nightlife

# %%
import sqlite3
conn = sqlite3.connect('mini_project_yelp.db')
c = conn.cursor()

# %%
c.execute("""CREATE TABLE Yelp_Overivew (
            id PRIMARY KEY,
            name varchar(255),
            review_count INT,
            rating decimal(18,2),
            price varchar(255),
            lat decimal(18,2),
            long decimal(18,2),
            category varchar(255)
            )""")

# %%
POI_df.to_sql('Yelp_Overview', conn, if_exists='replace', index = False)

# %%
c.execute(''' SELECT * FROM Yelp_Overview LIMIT 10''')
for row in c.fetchall():
     print (row)
# Out:
# ('Seven Lives Tacos y Mariscos', 1304, 4.5, '$', 43.6543411559068, -79.4004796072841, 'Restaurants')
# ('Banh Mi Boys', 1109, 4.5, '$', 43.64884, -79.39695, 'Restaurants')
# ('Gusto 101', 974, 4.0, '$$', 43.645002131066, -79.400309337027, 'Restaurants')
# ('Insomnia Restaurant & Lounge', 921, 4.0, '$$', 43.665961, -79.411003, 'Nightlife')
# ('Wvrst', 788, 4.0, '$$', 43.64418555054, -79.401014855291, 'Nightlife')
# ('Wvrst', 788, 4.0, '$$', 43.64418555054, -79.401014855291, 'Restaurants')
# ('Rol San', 738, 3.0, '$$', 43.6543527996563, -79.3983133882284, 'Restaurants')
# ('Ramen Isshin', 699, 4.5, '$$', 43.65634, -79.40689, 'Restaurants')
# ('Lee Restaurant', 635, 4.0, '$$$', 43.644144, -79.400384, 'Restaurants')
# ('Dumpling House Restaurant', 583, 3.5, '$', 43.65378, -79.3987, 'Restaurants')
